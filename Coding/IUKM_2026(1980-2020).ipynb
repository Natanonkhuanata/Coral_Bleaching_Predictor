# %% [markdown]
# # Coral Bleaching Dataset
#
# ## 🪸
#
# | Field | Description |
# |------|------------|
# | Site_ID | รหัสระบุพื้นที่เฉพาะ (Unique identifier) สำหรับแต่ละหน่วยพื้นที่ |
# | Sample_ID | รหัสระบุเหตุการณ์การสำรวจเฉพาะ สำหรับแต่ละครั้งที่มีการสำรวจ |
# | Data_Source | แหล่งที่มาของชุดข้อมูลเดิม |
# | Latitude_Degrees | พิกัดละติจูด (ค่าบวกคือทิศเหนือ, ค่าลบคือทิศใต้) |
# | Longitude_Degrees | พิกัดลองจิจูด (ค่าบวกคือทิศตะวันออก, ค่าลบคือทิศตะวันตก) |
# | Ocean_Name | ชื่อมหาสมุทรที่ทำการสำรวจ |
# | Reef_ID | รหัสระบุเฉพาะจากข้อมูลของ Reef Check |
# | Realm_Name | การระบุเขตทางทะเล (Realm) ตามนิยามของ MEOW |
# | Ecoregion_Name | การระบุเขตนิเวศ (Ecoregions) 150 เขต ตามนิยามของ Veron et al. |
# | Country_Name | ชื่อประเทศที่ทำการสำรวจ |
# | State_Island_Province_Name | ชื่อรัฐ, ดินแดน (เช่น กวม) หรือกลุ่มเกาะ (เช่น หมู่เกาะฮาวาย) |
# | City_Town_Name | ภูมิภาค, เมือง หรือเมืองที่ใกล้ที่สุดที่ทำการสำรวจ |
# | Site_Name | ชื่อพื้นที่ที่ยอมรับกันทั่วไปหรือชื่อที่ตั้งโดยทีมสำรวจ |
# | Distance_to_Shore | ระยะห่างของจุดสำรวจจากแผ่นดินที่ใกล้ที่สุด (เมตร) |
# | Exposure | การเปิดรับคลื่นลมของพื้นที่ (เปิดรับ, กำบัง หรือ "บางครั้ง") |
# | Turbidity | ค่าความขุ่นของน้ำ (Kd490) โดยใช้รัศมี 100 กม. เป็นตัววัดการลดทอนของแสงที่ความยาวคลื่น 490 นาโนเมตรตามความลึก |
# | Cyclone_Frequency | จำนวนเหตุการณ์พายุหมุนสะสมในช่วงปี 1964 ถึง 2014 |
# | Date_Day | วันที่ทำการสำรวจ |
# | Date_Month | เดือนที่ทำการสำรวจ |
# | Date_Year | ปีที่ทำการสำรวจ |
# | Depth_m | ระดับความลึกของจุดสำรวจ (เมตร) |
# | Substrate_Name | ประเภทของวัสดุพื้นใต้น้ำจากข้อมูล Reef Check |
# | Percent_Cover | ค่าเฉลี่ยการปกคลุมของพื้นผิว (เปอร์เซ็นต์) |
# | Bleaching_Level | ระดับการสำรวจ (ระดับประชากรหรือระดับโคโลนี) จาก Reef Check |
# | Percent_Bleaching | ค่าเฉลี่ยเปอร์เซ็นต์การฟอกขาว (จาก 4 เซกเมนต์ของแนวสำรวจหรือจากรหัสการฟอกขาว) |
# | ClimSST | อุณหภูมิพื้นผิวน้ำทะเลเฉลี่ยตามฤดูกาล (Climatological SST) |
# | Temperature_Kelvin | อุณหภูมิในหน่วยเคลวิน |
# | Temperature_Mean | อุณหภูมิเฉลี่ยในหน่วยองศาเซลเซียส |
# | Temperature_Minimum | อุณหภูมิต่ำสุดในหน่วยองศาเซลเซียส |
# | Temperature_Maximum | อุณหภูมิสูงสุดในหน่วยองศาเซลเซียส |
# | Temperature_Kelvin_Standard_Deviation | ส่วนเบี่ยงเบนมาตรฐานของอุณหภูมิในหน่วยเคลวิน |
# | Windspeed | ความเร็วลม (เมตรต่อชั่วโมง) |
# | SSTA | ความผิดปกติของอุณหภูมิพื้นผิวน้ำทะเล (SST รายสัปดาห์ ลบด้วย SST เฉลี่ยรายสัปดาห์ตามฤดูกาล) |
# | SSTA_Standard_Deviation | ส่วนเบี่ยงเบนมาตรฐานของ SSTA รายสัปดาห์ตลอดช่วงเวลาทั้งหมด |
# | SSTA_Mean | ค่าเฉลี่ยของ SSTA ตลอดช่วงเวลาทั้งหมด |
# | SSTA_Minimum | ค่า SSTA ต่ำสุดตลอดช่วงเวลาทั้งหมด |
# | SSTA_Maximum | ค่า SSTA สูงสุดตลอดช่วงเวลาทั้งหมด |
# | SSTA_Frequency | จำนวนสัปดาห์ในรอบ 52 สัปดาห์ก่อนหน้าที่มีค่า SSTA >= 1 องศาเซลเซียส |
# | SSTA_Frequency_Standard_Deviation | ส่วนเบี่ยงเบนมาตรฐานของความถี่ SSTA ตลอดช่วงเวลาทั้งหมด |
# | SSTA_FrequencyMax | ค่าความถี่ SSTA สูงสุดที่เคยเกิดขึ้นตลอดช่วงเวลาทั้งหมด |
# | SSTA_FrequencyMean | ค่าเฉลี่ยความถี่ของ SSTA ตลอดช่วงเวลาทั้งหมด |
# | SSTA_DHW | ค่าความร้อนสะสมรายสัปดาห์ (Degree Heating Weeks) ใน 12 สัปดาห์ล่าสุดเมื่อ SSTA >= 1 องศาเซลเซียส |
# | SSTA_DHW_Standard_Deviation | ส่วนเบี่ยงเบนมาตรฐานของ SSTA DHW ตลอดช่วงเวลาทั้งหมด |
# | SSTA_DHWMax | ค่า SSTA DHW สูงสุดที่เคยเกิดขึ้นตลอดช่วงเวลาทั้งหมด |
# | SSTA_DHWMean | ค่าเฉลี่ยของ SSTA DHW ตลอดช่วงเวลาทั้งหมด |
# | TSA | ความผิดปกติจากความเครียดจากความร้อน (SST รายสัปดาห์ ลบด้วยค่าสูงสุดของ SST เฉลี่ยรายสัปดาห์ตามฤดูกาล) |
# | TSA_Standard_Deviation | ส่วนเบี่ยงเบนมาตรฐานของ TSA ตลอดช่วงเวลาทั้งหมด |
# | TSA_Minimum | ค่า TSA ต่ำสุดตลอดช่วงเวลาทั้งหมด |
# | TSA_Maximum | ค่า TSA สูงสุดตลอดช่วงเวลาทั้งหมด |
# | TSA_Mean | ค่าเฉลี่ยของ TSA ตลอดช่วงเวลาทั้งหมด |
# | TSA_Frequency | จำนวนสัปดาห์ในรอบ 52 สัปดาห์ก่อนหน้าที่มีค่า TSA >= 1 องศาเซลเซียส |
# | TSA_Frequency_Standard_Deviation | ส่วนเบี่ยงเบนมาตรฐานของความถี่ TSA ตลอดช่วงเวลาทั้งหมด |
# | TSA_FrequencyMax | ค่าความถี่ TSA สูงสุดตลอดช่วงเวลาทั้งหมด |
# | TSA_FrequencyMean | ค่าเฉลี่ยความถี่ของ TSA ตลอดช่วงเวลาทั้งหมด |
# | TSA_DHW | ค่าความร้อนสะสมจาก TSA ใน 12 สัปดาห์ล่าสุดเมื่อ TSA >= 1 องศาเซลเซียส |
# | TSA_DHW_Standard_Deviation | ส่วนเบี่ยงเบนมาตรฐานของ TSA DHW ตลอดช่วงเวลาทั้งหมด |
# | TSA_DHWMax | ค่า TSA DHW สูงสุดตลอดช่วงเวลาทั้งหมด |
# | TSA_DHWMean | ค่าเฉลี่ยของ TSA DHW ตลอดช่วงเวลาทั้งหมด |
# | Date | วันที่ทำการสำรวจในรูปแบบ YYYY-MM-DD |
# | Site_Comments | ข้อคิดเห็นหรือข้อมูลเพิ่มเติมเกี่ยวกับพื้นที่สำรวจ |
# | Sample_Comments | ข้อคิดเห็นหรือข้อมูลเพิ่มเติมเกี่ยวกับเหตุการณ์การสำรวจ |
# | Bleaching_Comments | ข้อคิดเห็นหรือข้อมูลเพิ่มเติมเกี่ยวกับค่าการฟอกขาว |

# %%
import numpy as np
import pandas as pd
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_global = pd.read_csv("C:\\Github\\Coral_Bleaching_Predictor\\Data\\global_bleaching_environmental.csv" , na_values=['nd']) # old data
df_global
# Out:
#        Site_ID  Sample_ID Data_Source  Latitude_Degrees  Longitude_Degrees  \
# 0         2501   10324336      Donner           23.1630           -82.5260
# 1         3467   10324754      Donner          -17.5750          -149.7833
# 2         1794   10323866      Donner           18.3690           -64.5640
# 3         8647   10328028      Donner           17.7600           -64.5680
# 4         8648   10328029      Donner           17.7690           -64.5830
# ...        ...        ...         ...               ...                ...
# 41356    15446   10310562  Reef_Check           -8.3651           116.0844
# 41357    15456   10310527  Reef_Check           -8.3473           116.0503
# 41358    15456   10310527  Reef_Check           -8.3473           116.0503
# 41359    15457   10310536  Reef_Check           -8.3445           116.0629
# 41360    15457   10310536  Reef_Check           -8.3445           116.0629
#
# ...

# %%
#Check NAN Data and by what percentage
def nan_check(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent_1 = data.isnull().sum()/data.isnull().count()*100
    percent_2 = (np.round(percent_1, 1)).sort_values(ascending=False)
    missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
    return missing_data , percent_2

# %%
df_global[['Exposure']].value_counts()
# Out:
# Exposure
# Sheltered    23913
# Exposed      14321
# Sometimes     3127
# Name: count, dtype: int64

# %%
missing_data , percent = nan_check(df_global)

# %%
missing_data[['%']]
# Out:
#                        %
# Site_Comments       94.5
# Bleaching_Comments  93.5
# Sample_Comments     92.8
# Site_Name           83.2
# Bleaching_Level     45.5
# ...                  ...
# Cyclone_Frequency    0.0
# Date_Day             0.0
# Date_Month           0.0
# Date_Year            0.0
# Site_ID              0.0
#
# [62 rows x 1 columns]

# %%
def Columns_percent_missing(df, col):
    
    count_less = 0
    count_more = 0
    Index_more = []
    Index_less = []
    for_drop = []
    for idx, value in df[col].items():
        if value >= 50:
            count_more += 1
            Index_more.append(idx)
            for_drop.append(idx)
        elif value < 50:
            count_more += 1
            Index_less.append(idx)
            
    print("\n")
    print(f"more than 50% : {count_more}")
    print(f"less than 50% : {count_less}")
    print(f"Index_more : {len(Index_more)} attribuue : {Index_more}")
    print(f"Index_less : {len(Index_less)} attribuue : {Index_less}")
    print(f"for_drop : {len(for_drop)} attribuue : {for_drop}")
    
    return for_drop
    
columns_drop = Columns_percent_missing(missing_data,'%')
print("Missing values more than 50% : Delete")
# Out:
# more than 50% : 62
# less than 50% : 0
# Index_more : 4 attribuue : ['Site_Comments', 'Bleaching_Comments', 'Sample_Comments', 'Site_Name']
# ...

# %%
df_global[['Percent_Bleaching','Percent_Cover']]
# Out:
#        Percent_Bleaching  Percent_Cover
# 0                   50.2            NaN
# 1                   50.7            NaN
# 2                   50.9            NaN
# 3                   50.9            NaN
# 4                   50.9            NaN
# ...                  ...            ...
# 41356                NaN          17.50
# 41357                NaN          13.75
# 41358                NaN           0.62
# 41359                NaN          26.88
# 41360                NaN          11.25
#
# [41361 rows x 2 columns]

# %%
df_global['Exposure'].value_counts()
# Out:
# Exposure
# Sheltered    23913
# Exposed      14321
# Sometimes     3127
# Name: count, dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ## Chapter 1 : Data analysis and insight data (Cleaning data)
# - using ffill for missing values

# %% [markdown]
# #### Pipeline Cleaning data
# -  Missing data more than 50%   : variable is df_Clean_missing
# -  SSTA > 0   : variable is df_SSTA_Clean
# -  Land and Ocean Detection : df_Land_Ocean_formodel
# -  Data Duplicate from area : df_Duplicates_Date
# -  Date Completeness
# -  Environmental / SST Metrics
# -  Outlier ด้วย IQR หรือ Z-score

# %%
# for_drop : 4 attribuue : ['Site_Comments', 'Bleaching_Comments', 'Sample_Comments', 'Site_Name']
def Cleaning_missing_values(df, col): # col : list of columns to drop because of missing values more than 50%
    df_Clean_missing = df.drop(columns=col, errors='ignore')
    
    return df_Clean_missing

df_Clean_missing = Cleaning_missing_values(df_global, columns_drop)

df_Clean_missing
print(f"feature : {len(df_global.columns)} --> drop : {len(df_Clean_missing.columns)} so delete = {len(columns_drop)} attribue")
print(f"data : {len(df_Clean_missing)} --> drop : {len(df_Clean_missing)} so delete = 0 rows")
# Out:
# feature : 62 --> drop : 58 so delete = 4 attribue
# data : 41361 --> drop : 41361 so delete = 0 rows

# %%
def SSTA_more_than_zero(df):  # SSTA : Sea surface temperature anomaly
    df_SSTA_Clean = df[df['SSTA'] >= 0]
    return df_SSTA_Clean

df_SSTA_Clean = SSTA_more_than_zero(df_Clean_missing)
print(f"feature : {len(df_Clean_missing.columns)} --> drop : {len(df_SSTA_Clean.columns)} so delete = 0 attribue")
print(f"data : {len(df_Clean_missing)} --> drop : {len(df_SSTA_Clean)} so delete = {len(df_Clean_missing) - len(df_SSTA_Clean)} rows")
# Out:
# feature : 58 --> drop : 58 so delete = 0 attribue
# data : 41361 --> drop : 26236 so delete = 15125 rows

# %%
nan_check(df_SSTA_Clean)
# Out:
# (                                       Total     %
#  Bleaching_Level                        11887  45.3
#  Substrate_Name                          8343  31.8
#  Reef_ID                                 8267  31.5
#  Percent_Cover                           8150  31.1
#  Percent_Bleaching                       3899  14.9
#  Depth_m                                 1400   5.3
#  City_Town_Name                           695   2.6
#  State_Island_Province_Name                68   0.3
#  SSTA_Minimum                              22   0.1
#  Ecoregion_Name                             3   0.0
#  Country_Name                               1   0.0
#  SSTA_DHW                                   0   0.0
#  SSTA_FrequencyMean                         0   0.0
#  SSTA_DHW_Standard_Deviation                0   0.0
#  SSTA_DHWMax                                0   0.0
#  SSTA_DHWMean                               0   0.0
#  TSA                                        0   0.0
# ...

# %%
print(df_SSTA_Clean.select_dtypes(include=['object']).columns)
print("-"*100)
print(df_SSTA_Clean.select_dtypes(include=['number']).columns)
# Out:
# Index(['Data_Source', 'Ocean_Name', 'Reef_ID', 'Realm_Name', 'Ecoregion_Name',
#        'Country_Name', 'State_Island_Province_Name', 'City_Town_Name',
#        'Exposure', 'Substrate_Name', 'Bleaching_Level', 'Date'],
#       dtype='object')
# ----------------------------------------------------------------------------------------------------
# Index(['Site_ID', 'Sample_ID', 'Latitude_Degrees', 'Longitude_Degrees',
#        'Distance_to_Shore', 'Turbidity', 'Cyclone_Frequency', 'Date_Day',
#        'Date_Month', 'Date_Year', 'Depth_m', 'Percent_Cover',
#        'Percent_Bleaching', 'ClimSST', 'Temperature_Kelvin',
#        'Temperature_Mean', 'Temperature_Minimum', 'Temperature_Maximum',
#        'Temperature_Kelvin_Standard_Deviation', 'Windspeed', 'SSTA',
#        'SSTA_Standard_Deviation', 'SSTA_Mean', 'SSTA_Minimum', 'SSTA_Maximum',
#        'SSTA_Frequency', 'SSTA_Frequency_Standard_Deviation',
#        'SSTA_FrequencyMax', 'SSTA_FrequencyMean', 'SSTA_DHW',
# ...

# %%
## ffill and bfill
def ffill_bfill(df):
    df_ffill = df.fillna(method='ffill', inplace=False)
    df_bfill = df.fillna(method='bfill', inplace=False)
    return df_ffill, df_bfill

df_ffill, df_bfill = ffill_bfill(df_SSTA_Clean)
# Out:
# C:\Users\superuser\AppData\Local\Temp\ipykernel_18720\2406427183.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method='ffill', inplace=False)
# C:\Users\superuser\AppData\Local\Temp\ipykernel_18720\2406427183.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method='bfill', inplace=False)

# %%
df_ffill[['Reef_ID', 'Bleaching_Level', 'Percent_Cover','Substrate_Name']]
# Out:
#                      Reef_ID Bleaching_Level  Percent_Cover  \
# 1                        NaN             NaN            NaN
# 2                        NaN             NaN            NaN
# 4                        NaN             NaN            NaN
# 5                        NaN             NaN            NaN
# 6                        NaN             NaN            NaN
# ...                      ...             ...            ...
# 41351  54.04.576E.12.40.753N      Population          55.00
# 41352  54.04.576E.12.40.753N      Population          41.25
# 41353  54.04.576E.12.40.753N      Population          32.94
# 41357  116.3.1.1E.8.20.50.2S      Population          13.75
# 41358  116.3.1.1E.8.20.50.2S      Population           0.62
#
#                  Substrate_Name
# 1                           NaN
# 2                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# ...                         ...
# ...

# %%
nan_check(df_ffill)
# Out:
# (                                       Total     %
#  Reef_ID                                 4875  18.6
#  Bleaching_Level                         4875  18.6
#  Percent_Cover                           4875  18.6
#  Substrate_Name                          4875  18.6
#  Site_ID                                    0   0.0
#  SSTA_DHWMean                               0   0.0
#  SSTA_Mean                                  0   0.0
#  SSTA_Minimum                               0   0.0
#  SSTA_Maximum                               0   0.0
#  SSTA_Frequency                             0   0.0
#  SSTA_Frequency_Standard_Deviation          0   0.0
#  SSTA_FrequencyMax                          0   0.0
#  SSTA_FrequencyMean                         0   0.0
#  SSTA_DHW                                   0   0.0
#  SSTA_DHW_Standard_Deviation                0   0.0
#  SSTA_DHWMax                                0   0.0
#  TSA                                        0   0.0
# ...

# %% [markdown]
# ##

# %% [markdown]
# ## Ploting insight of data

# %%
def Linear_correlation(df , size):
    df_corr = df.select_dtypes(exclude=['object'])

    corr_matrix = df_corr.corr()  # ✅ สำคัญมาก

    # สร้าง mask เพื่อซ่อนครึ่งบน
    mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

    plt.figure(figsize=size)

    sns.heatmap(
        corr_matrix,
        mask=mask,
        #annot=True,
        fmt=".2f",
        cmap="coolwarm",
        vmin=-1,
        vmax=1,
        center=0,
        square=True,
        linewidths=.5,
        cbar_kws={"shrink": .8}
    )

    plt.title("Linear Correlations Between all Parameters", pad=20)

    plt.xticks(rotation=90)
    plt.yticks(rotation=0)

    plt.show()

# %%
def Correlation_mretix(data, columns):
    sns.set_theme(style="white", font_scale=1.2)

    fig, ax = plt.subplots(
        figsize=(12, 7)
    )

    corr = data[columns].corr()

    sns.heatmap(
        corr,
        annot=True,
        fmt=".2f",
        cmap="coolwarm",
        vmin=-1,
        vmax=1,
        center=0,
        linewidths=0.5,
        square=True,
        cbar_kws={
            "shrink": 0.8,
            "label": "Correlation"
        }
    )

    plt.xticks(rotation=30, ha="right")
    plt.yticks(rotation=0)

    fig.suptitle(
        "Correlation Heatmap of Preprocessed Dataset",
        fontsize=18,
        fontweight="bold",
        x=0.5,
        y=1.02,
        ha="center"
    )


    plt.show()

# %%
def Plotting_feature_target(df,col_feature, col_target='Percent_Bleaching'):
    
    X = df[col_feature]
    y = df[col_target]
    
    plt.figure(figsize=(6,4))
    plt.scatter(X, y, color='white', edgecolor='black', alpha=0.7)
    plt.xlabel(col_feature)
    plt.ylabel(col_target)
    plt.title(f'{col_feature} vs {col_target}')
    plt.show()

# %%
def plotting_distribution(data, columns):
    for col in columns:
        norm_fit = ss.norm.fit(data[col])
        datasortvalues = data[col].sort_values()
        plt.figure(figsize=(8,6))
        plt.hist(data[[col]], density=True, bins=30, color='skyblue', edgecolor='black')
        plt.plot(datasortvalues, ss.norm.pdf(datasortvalues, *norm_fit), color='red', linewidth=2)
        plt.xlabel(col)
        plt.ylabel('Density')
        plt.title(f'Distribution of {col}')
        plt.show()

# %%
plotting_distribution(df_ffill, ['Percent_Bleaching'])

# %%
plotting_distribution(df_ffill, ['SSTA'])

# %%
plotting_distribution(df_ffill, ['Depth_m'])

# %%
plotting_distribution(df_ffill, ['Latitude_Degrees'])

# %%
plotting_distribution(df_ffill, ['Longitude_Degrees'])

# %%
plotting_distribution(df_ffill, ['ClimSST'])

# %%
def Histrogram_data(df,col):
    plt.hist(df[[col]], density=True, bins=30, color='skyblue', edgecolor='black')
    plt.xlabel(col)
    plt.ylabel('Density')
    plt.title(f'Histrogram of {col}')
    plt.show()
    
    Hight = []
    Low = []
    zero = 0
    
    for i in df[col]:
        if i == 0:
            text = "Data not values"
            zero += 1
        elif i >= 30:
            Hight.append(i)
        else:
            Low.append(i)
    if len(Hight) != 0:
        print(f"columns have dataset : {len(df[col])}")
        print(f"columns have maximum data : {len(Hight)} is {Hight[0]} from more than >30%")
        print(f"columns have minimum data : {len(Low)} is {Low[0]} from less than <30%")
    else:
        print(f"{text} and count = {zero}")

# %%
Linear_correlation(df_ffill,(12,10))

# %%
Plotting_feature_target(df_ffill, 'SSTA')

# %%
Plotting_feature_target(df_ffill, 'TSA_DHW')

# %%
Plotting_feature_target(df_ffill, 'Temperature_Kelvin')

# %%
df_forRF  = df_ffill.select_dtypes(exclude=['object']).copy()
df_forRF = df_forRF[df_forRF.drop(columns=['Percent_Cover'], errors='ignore').columns]

# %%
nan_check(df_forRF)
# Out:
# (                                       Total    %
#  Site_ID                                    0  0.0
#  SSTA_Maximum                               0  0.0
#  SSTA_Frequency_Standard_Deviation          0  0.0
#  SSTA_FrequencyMax                          0  0.0
#  SSTA_FrequencyMean                         0  0.0
#  SSTA_DHW                                   0  0.0
#  SSTA_DHW_Standard_Deviation                0  0.0
#  SSTA_DHWMax                                0  0.0
#  SSTA_DHWMean                               0  0.0
#  TSA                                        0  0.0
#  TSA_Standard_Deviation                     0  0.0
#  TSA_Minimum                                0  0.0
#  TSA_Maximum                                0  0.0
#  TSA_Mean                                   0  0.0
#  TSA_Frequency                              0  0.0
#  TSA_Frequency_Standard_Deviation           0  0.0
#  TSA_FrequencyMax                           0  0.0
# ...

# %%
nan_check(df_forRF.select_dtypes(exclude=['object']))
# Out:
# (                                       Total    %
#  Site_ID                                    0  0.0
#  SSTA_Maximum                               0  0.0
#  SSTA_Frequency_Standard_Deviation          0  0.0
#  SSTA_FrequencyMax                          0  0.0
#  SSTA_FrequencyMean                         0  0.0
#  SSTA_DHW                                   0  0.0
#  SSTA_DHW_Standard_Deviation                0  0.0
#  SSTA_DHWMax                                0  0.0
#  SSTA_DHWMean                               0  0.0
#  TSA                                        0  0.0
#  TSA_Standard_Deviation                     0  0.0
#  TSA_Minimum                                0  0.0
#  TSA_Maximum                                0  0.0
#  TSA_Mean                                   0  0.0
#  TSA_Frequency                              0  0.0
#  TSA_Frequency_Standard_Deviation           0  0.0
#  TSA_FrequencyMax                           0  0.0
# ...

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# ## Chapter 2: RF Feature Importance → drop redundant features
# - GridSearchCV for discoed the best hyperparameter

# %%
# machine leaarning
import sklearn
from sklearn.preprocessing import StandardScaler , MinMaxScaler , PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score  , mean_absolute_percentage_error
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.utils import shuffle
from sklearn.cluster import KMeans
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

# %%
def Metric_result(model , X_train , X_test , y_train , y_test):
    print(f"Score on training data: {(model.score(X_train, y_train)).round(3)}") # score from training
    pred = model.predict(X_test)
    print("-" * 30)

    test_mse = mean_squared_error(y_test, pred) # Mean_Squaed_error
    print("Test MSE:", test_mse.round(3))
    print("-" * 30)


    test_rmse = np.sqrt(mean_squared_error(y_test, pred)) # Root_mean_squared_error
    print(f"Test RMSE : {test_rmse.round(3)}")
    print("-" * 30)

    test_r2 = r2_score(y_test, pred) # R2_squared
    print(f"Test R2 Score : {test_r2.round(3)}")
    print("-" * 30)

    test_mae = mean_absolute_error(y_test, pred) # Mean_Absolute_error
    print(f"Mean Absolute Error : {test_mae.round(3)}")
    print("-" * 30)

    test_mape = mean_absolute_percentage_error(y_test, pred) # Mean_Absolute_Percentage_Error
    print(f"Mean Absolute Percentage Error : {test_mape.round(3)}")
    print("-" * 30)
    
    print(pred.shape)
    print(y_test.shape)

# %%
def RESULT_K_FOLD(results,cv):
    r2 = results['test_r2']
    rmse = np.sqrt(-results['test_neg_mean_squared_error'])
    mae = -results['test_neg_mean_absolute_error']

    print(f"R2 mean: {r2.mean().round(2)} and R2 of {cv} : {r2.round(2)}")
    print(f"RMSE mean: {rmse.mean().round(2)} and RMSE of {cv} : {rmse.round(2)}")
    print(f"MAE mean: {mae.mean().round(2)} and MAE of {cv} : {mae.round(2)}")

# %%
RF_fristEXfeature = df_forRF[df_forRF.drop(columns=['Percent_Bleaching'], errors='ignore').columns]
RF_fristEXtarget = df_forRF['Percent_Bleaching']

# tranform data is ValuesVie
RF_fristEXfeature_Values = RF_fristEXfeature.values
RF_fristEXtarget_Values = RF_fristEXtarget.values

# %%
# devide data using train_test_split
seed = 42
X_train , X_test , y_train , y_test = train_test_split(RF_fristEXfeature_Values, RF_fristEXtarget_Values, test_size=0.3 , random_state=42)

X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((18365, 44), (7871, 44), (18365,), (7871,))

# %%
param_grid = {
    'n_estimators' : [100 , 200 , 300 , 400 , 500],
    'max_features' : ['sqrt', 'log2', None],
    'max_depth' : [10 , 20 ,30 , 40 , 50],
    'min_samples_split' : [2 , 5 , 10],
    'min_samples_leaf' : [1 , 2 , 3 , 4],
    'bootstrap' : [True , False],
}

# %%
# K-Fold Cross validation third experiment
rfr_best_params = RandomForestRegressor(
    n_estimators=200,
    max_depth= 30,
    max_features= 'sqrt',
    min_samples_leaf= 2,
    min_samples_split= 2,
    criterion= 'squared_error',
    bootstrap= False,
    random_state=seed,
    verbose=2
)

rfr_cross_validation_third = cross_validate(rfr_best_params, X_train, y_train, cv=5 , scoring= ['r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'])
# Out:
# building tree 1 of 200
# building tree 2 of 200
# building tree 3 of 200
# building tree 4 of 200
# building tree 5 of 200
# building tree 6 of 200
# building tree 7 of 200
# building tree 8 of 200
# building tree 9 of 200
# building tree 10 of 200
# building tree 11 of 200
# building tree 12 of 200
# building tree 13 of 200
# building tree 14 of 200
# building tree 15 of 200
# building tree 16 of 200
# building tree 17 of 200
# building tree 18 of 200
# building tree 19 of 200
# building tree 20 of 200
# building tree 21 of 200
# building tree 22 of 200
# building tree 23 of 200
# building tree 24 of 200
# building tree 25 of 200
# building tree 26 of 200
# building tree 27 of 200
# building tree 28 of 200
# building tree 29 of 200
# building tree 30 of 200
# building tree 31 of 200
# building tree 32 of 200
# building tree 33 of 200
# building tree 34 of 200
# building tree 35 of 200
# building tree 36 of 200
# building tree 37 of 200
# building tree 38 of 200
# ...

# %%
RESULT_K_FOLD(rfr_cross_validation_third,5)
# Out:
# R2 mean: 0.86 and R2 of 5 : [0.88 0.85 0.87 0.86 0.87]
# RMSE mean: 13.47 and RMSE of 5 : [12.78 13.85 13.32 13.64 13.77]
# MAE mean: 6.52 and MAE of 5 : [6.2  6.78 6.59 6.52 6.5 ]

# %%
rfr_best_params.fit(X_train, y_train)
# Out:
# building tree 1 of 200
# building tree 2 of 200
# building tree 3 of 200
# building tree 4 of 200
# building tree 5 of 200
# building tree 6 of 200
# building tree 7 of 200
# building tree 8 of 200
# building tree 9 of 200
# building tree 10 of 200
# building tree 11 of 200
# building tree 12 of 200
# building tree 13 of 200
# building tree 14 of 200
# building tree 15 of 200
# building tree 16 of 200
# building tree 17 of 200
# building tree 18 of 200
# building tree 19 of 200
# building tree 20 of 200
# building tree 21 of 200
# building tree 22 of 200
# building tree 23 of 200
# building tree 24 of 200
# building tree 25 of 200
# building tree 26 of 200
# building tree 27 of 200
# building tree 28 of 200
# building tree 29 of 200
# building tree 30 of 200
# building tree 31 of 200
# building tree 32 of 200
# building tree 33 of 200
# building tree 34 of 200
# building tree 35 of 200
# building tree 36 of 200
# building tree 37 of 200
# building tree 38 of 200
# ...

# %%
X_test.shape , y_test.shape
# Out:
# ((7871, 44), (7871,))

# %%
Metric_result(rfr_best_params, X_train, X_test, y_train, y_test)
# Out:
# [Parallel(n_jobs=1)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Done  40 tasks      | elapsed:    0.0s
# Score on training data: 0.983
# ------------------------------
# Test MSE: 160.4
# ------------------------------
# Test RMSE : 12.665
# ------------------------------
# Test R2 Score : 0.88
# ------------------------------
# Mean Absolute Error : 5.95
# ------------------------------
# Mean Absolute Percentage Error : 3645152304686917.0
# ------------------------------
# (7871,)
# (7871,)
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.1s finished

# %%
y_test_pred = rfr_best_params.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.1s finished

# %%
y_test = y_test.ravel()
y_test_pred = y_test_pred.ravel()

plt.figure(figsize=(10,6))

plt.scatter(y_test_pred, y_test, 
            color='orange', alpha=1, label='Actual values')


plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Random Forest Prediction vs True Values')

plt.legend()
plt.show()

# %%
def feature_importance(model, feature_train):
    importances = model.feature_importances_
    feature_names = feature_train.columns
   
    df_importance = pd.DataFrame({
        'feature': feature_names,
        'importance': importances
    }).sort_values(by='importance', ascending=False)
    print(f"Columns have all : {len(df_importance)}")
    
    return df_importance.round(2)

# %%
feature_importance(rfr_best_params, RF_fristEXfeature)
# Out:
# Columns have all : 44
#                                   feature  importance
# 5                               Turbidity        0.26
# 9                               Date_Year        0.18
# 1                               Sample_ID        0.07
# 0                                 Site_ID        0.05
# 3                       Longitude_Degrees        0.02
# 19                SSTA_Standard_Deviation        0.02
# 2                        Latitude_Degrees        0.02
# 40                                TSA_DHW        0.02
# 10                                Depth_m        0.02
# 27                               SSTA_DHW        0.02
# 31                                    TSA        0.02
# 12                     Temperature_Kelvin        0.01
# 23                         SSTA_Frequency        0.01
# 13                       Temperature_Mean        0.01
# 7                                Date_Day        0.01
# 35                               TSA_Mean        0.01
# ...

# %% [markdown]
# rfr_chaptertwo = RandomForestRegressor(random_state=seed)
# rfr_chaptertwoGridsearchCV = GridSearchCV(estimator=rfr_chaptertwo, param_grid=param_grid, cv=5, verbose=2)
#
# rfr_chaptertwoGridsearchCV.fit(Xfrist_train, yfrist_train)

# %% [markdown]
# rfr_chaptertwoGridsearchCV.best_params_

# %% [markdown]
# ##

# %% [markdown]
# ## Chapter 3 : Principle component analysis (PCA)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(RF_fristEXfeature_Values)
X_scaled.round(4)
# Out:
# array([[-0.2433,  0.1439, -1.5985, ..., -0.543 , -0.949 , -0.3285],
#        [-0.2509,  0.1432,  0.659 , ..., -0.2841,  0.1728, -0.2734],
#        [-0.2196,  0.1462,  0.6213, ..., -0.3681, -0.5906, -0.2813],
#        ...,
#        [-0.2125,  0.119 , -0.6994, ...,  0.5416,  1.8115,  0.1198],
#        [-0.1884,  0.1336, -1.019 , ..., -0.1092, -0.4113,  0.0333],
#        [-0.1884,  0.1336, -1.019 , ..., -0.1092, -0.4113,  0.0333]])

# %% [markdown]
# #### from Scarch

# %%
scaler.mean_.round(4)
# Out:
# array([ 5.66173428e+04,  1.01260771e+07,  7.87650000e+00,  3.49771000e+01,
#         3.93009710e+03,  6.78000000e-02,  5.21305000e+01,  1.60604000e+01,
#         6.96760000e+00,  2.00820890e+03,  7.05670000e+00,  2.93915400e+02,
#         3.01816000e+02,  3.00352200e+02,  2.95715800e+02,  3.05076800e+02,
#         1.68630000e+00,  4.57750000e+00,  7.17500000e-01,  9.10400000e-01,
#         0.00000000e+00, -3.51020000e+00,  3.44580000e+00,  8.17660000e+00,
#         4.89330000e+00,  2.41965000e+01,  5.33990000e+00,  3.67990000e+00,
#         3.07650000e+00,  1.88154000e+01,  2.08500000e+00, -4.69100000e-01,
#         1.68490000e+00, -6.55650000e+00,  2.78010000e+00, -1.92220000e+00,
#         2.25930000e+00,  1.77190000e+00,  8.17270000e+00,  1.09950000e+00,
#         1.53460000e+00,  1.44600000e+00,  1.05803000e+01,  6.07600000e-01])

# %%
scaler.var_.round(4)
# Out:
# array([4.77332285e+10, 1.90688056e+12, 2.53505300e+02, 1.05100016e+04,
#        2.08817269e+08, 3.90000000e-03, 5.96484000e+01, 6.14685000e+01,
#        7.95330000e+00, 3.58091000e+01, 1.95021000e+01, 2.24636200e+02,
#        3.56810000e+00, 2.49450000e+00, 6.98110000e+00, 1.69260000e+00,
#        5.27200000e-01, 3.92470000e+00, 3.54100000e-01, 5.67000000e-02,
#        0.00000000e+00, 4.14700000e-01, 1.29380000e+00, 4.04318000e+01,
#        1.67210000e+00, 4.68375000e+01, 6.24430000e+00, 2.64977000e+01,
#        2.72880000e+00, 8.13984000e+01, 1.98770000e+00, 2.30560000e+00,
#        5.30800000e-01, 5.78590000e+00, 9.02900000e-01, 1.21280000e+00,
#        1.04813000e+01, 5.91200000e-01, 1.92981000e+01, 4.67750000e+00,
#        1.64308000e+01, 2.04210000e+00, 3.90462000e+01, 1.61690000e+00])

# %%
# formula of z-score or Standardization
z_score = (RF_fristEXfeature_Values - scaler.mean_) / np.sqrt(scaler.var_)
# Out:
# C:\Users\superuser\AppData\Local\Temp\ipykernel_18720\2630121490.py:2: RuntimeWarning: invalid value encountered in divide
#   z_score = (RF_fristEXfeature_Values - scaler.mean_) / np.sqrt(scaler.var_)

# %%
z_score.round(4)
# Out:
# array([[-0.2433,  0.1439, -1.5985, ..., -0.543 , -0.949 , -0.3285],
#        [-0.2509,  0.1432,  0.659 , ..., -0.2841,  0.1728, -0.2734],
#        [-0.2196,  0.1462,  0.6213, ..., -0.3681, -0.5906, -0.2813],
#        ...,
#        [-0.2125,  0.119 , -0.6994, ...,  0.5416,  1.8115,  0.1198],
#        [-0.1884,  0.1336, -1.019 , ..., -0.1092, -0.4113,  0.0333],
#        [-0.1884,  0.1336, -1.019 , ..., -0.1092, -0.4113,  0.0333]])

# %%
## PCA
pca = PCA(n_components= X_scaled.shape[1])

pca.fit_transform(X_scaled)
print(f"Explained_variance (n_components = {pca.n_components}) = {pca.explained_variance_}") # Eigenvalues
print("-" * 100)
print(f"Explaned_variance_ratio (n_components = {pca.n_components}) = {pca.explained_variance_ratio_}") # Variance Ratio
print("-" * 100)
print(f"Total explained variance ratio: {np.sum(pca.explained_variance_ratio_).round(4)}")
# Out:
# Explained_variance (n_components = 44) = [1.22399939e+01 6.22500608e+00 2.81135556e+00 2.75622914e+00
#  2.08901114e+00 1.55841086e+00 1.29895330e+00 1.20935814e+00
#  1.12197700e+00 1.06546201e+00 1.02052730e+00 9.52787016e-01
#  9.12092313e-01 7.97957002e-01 7.79011308e-01 7.51771220e-01
#  6.79545956e-01 6.35408233e-01 5.75460573e-01 5.55242731e-01
#  5.21403003e-01 4.67766065e-01 4.32760700e-01 2.90436856e-01
#  2.68772980e-01 2.27592543e-01 1.74743092e-01 1.25666200e-01
#  9.57866838e-02 9.00912041e-02 8.58309451e-02 5.89601360e-02
#  4.35854982e-02 3.38981030e-02 1.96434402e-02 1.05533236e-02
#  8.53704343e-03 4.52675523e-03 3.91998721e-03 1.53084270e-03
#  6.73428419e-05 3.35875444e-06 2.12266998e-06 5.10021829e-32]
# ----------------------------------------------------------------------------------------------------
# Explaned_variance_ratio (n_components = 44) = [2.84640172e-01 1.44762065e-01 6.53778697e-02 6.40959089e-02
# ...

# %%
def scree_plot(X, n_components, with_cumulative=False, show_data_label=False, figsize=(10, 7)):
    '''
    PCA scree plot with cumulative
    '''
    scaler = StandardScaler()
    X_t=scaler.fit_transform(X)

    max_components = min(X.shape)
    x=np.arange(1, n_components+1)
    pca = PCA(n_components=max_components)
    pca.fit_transform(X_t)
    y1=pca.explained_variance_ratio_[:n_components]
    y2=np.cumsum(pca.explained_variance_ratio_)[:n_components]
    
    plt.figure(figsize=figsize)
    
    if n_components > 20:
        marker = None
    else:
        marker = 'o'
    if with_cumulative:
        plt.plot(x, y2, linestyle='--', marker=marker, label='cumulative', color='salmon')
        
    plt.plot(x, y1, linestyle='-', marker=marker, label='individual', color='deepskyblue')
    plt.title('explained variance ratio')
    plt.xlabel('# of components')
    plt.ylabel('proportion of variance explained')
    plt.legend()
    if with_cumulative:
        [plt.axhline(y=xl, color='.7', linestyle='--') for xl in [.8, .9, .95, 1]]
    plt.grid(axis='x')

    if show_data_label:
        for n, v, cv in zip(np.nditer(x, flags=['refs_ok']), 
                            np.nditer(y1, flags=['refs_ok']),
                            np.nditer(y2, flags=['refs_ok'])):
                plt.text(n+.02, v+.02, f'{v*100:.2f}%', fontsize=10)
                if with_cumulative:
                    plt.text(n+.02, cv+.02, f'{cv*100:.2f}%', fontsize=10)

# %%
X_scaled.shape
# Out:
# (26236, 44)

# %%
def discover_optimal_PCA_components(X, threshold= 0.95):
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    pca = PCA(n_components=X_scaled.shape[1])
    pca.fit_transform(X_scaled)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    optimal_components = np.argmax(cumulative_variance >= threshold) + 1
    
    return optimal_components

optimal_n_components = discover_optimal_PCA_components(X_scaled, threshold= 0.95)
print(f"Optimal number of PCA components to retain at least 95% vaeriance: {optimal_n_components}")
# Out:
# Optimal number of PCA components to retain at least 95% vaeriance: 22

# %%
pca = PCA(n_components= X_scaled.shape[1] - 22)

pca.fit_transform(X_scaled)
print(f"Explained_variance (n_components = {pca.n_components}) = {pca.explained_variance_}") # Eigenvalues
print("-" * 100)
print(f"Explaned_variance_ratio (n_components = {pca.n_components}) = {pca.explained_variance_ratio_}") # Variance Ratio
print("-" * 100)
print(f"Total explained variance ratio: {np.sum(pca.explained_variance_ratio_).round(4)}")
scree_plot(X_scaled, X_scaled.shape[1] - 22, True, True)
# Out:
# Explained_variance (n_components = 22) = [12.23999393  6.22500608  2.81135556  2.75622914  2.08901114  1.55841086
#   1.2989533   1.20935814  1.121977    1.06546201  1.0205273   0.95278702
#   0.91209231  0.797957    0.77901131  0.75177122  0.67954596  0.63540823
#   0.57546057  0.55524273  0.521403    0.46776606]
# ----------------------------------------------------------------------------------------------------
# Explaned_variance_ratio (n_components = 22) = [0.28464017 0.14476207 0.06537787 0.06409591 0.0485798  0.03624073
#  0.03020706 0.02812354 0.02609149 0.02477724 0.02373229 0.02215699
#  0.02121064 0.01855643 0.01811585 0.01748239 0.01580279 0.01477637
#  0.01338229 0.01291213 0.01212519 0.01087787]
# ----------------------------------------------------------------------------------------------------
# Total explained variance ratio: 0.954

# %%
scree_plot(X_scaled, X_scaled.shape[1], False, True, (20, 7))

# %%
dpc = pd.DataFrame(pca.components_.T ,
                   index=RF_fristEXfeature.columns,
                   columns=[f'PC{i+1}' for i in range(pca.components_.shape[0])]).round(4)
dpc.style.applymap(
    lambda x: 'background-color: yellow' if abs(x) > 0.5 else ''
)
# Out:
# C:\Users\superuser\AppData\Local\Temp\ipykernel_18720\1543022485.py:4: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   dpc.style.applymap(
# <style type="text/css">
# #T_2843f_row1_col9, #T_2843f_row5_col15, #T_2843f_row5_col18, #T_2843f_row7_col10, #T_2843f_row7_col12, #T_2843f_row8_col12, #T_2843f_row9_col6, #T_2843f_row11_col13, #T_2843f_row17_col17, #T_2843f_row18_col21, #T_2843f_row21_col20 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2843f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2843f_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_2843f_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_2843f_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_2843f_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_2843f_level0_col4" class="col_heading level0 col4" >PC5</th>
# ...

# %%
print(pca.components_.round(4)) # Eigenvectors
print(pca.components_.shape)
# Out:
# [[-2.980e-02 -3.000e-02  3.560e-02  7.880e-02 -1.100e-03  9.090e-02
#    1.800e-03 -9.000e-04 -8.000e-04 -2.000e-04 -3.330e-02  1.720e-02
#    5.200e-03 -9.440e-02 -1.494e-01  6.630e-02  1.545e-01 -2.130e-02
#    1.332e-01  2.559e-01  0.000e+00 -1.551e-01  1.786e-01  1.375e-01
#    1.324e-01  1.446e-01  2.607e-01  1.747e-01  2.715e-01  2.285e-01
#    2.708e-01  5.820e-02  1.555e-01 -1.332e-01  1.766e-01 -6.400e-02
#    1.919e-01  1.704e-01  1.881e-01  2.259e-01  1.860e-01  2.404e-01
#    2.292e-01  2.215e-01]
#  [ 1.330e-02 -1.105e-01  1.015e-01 -6.300e-03  2.670e-02  1.121e-01
#    6.720e-02 -4.900e-03  2.240e-02  0.000e+00 -3.500e-02 -9.100e-03
#   -1.541e-01 -2.911e-01 -3.191e-01 -6.040e-02  3.204e-01  7.610e-02
#   -5.740e-02 -2.040e-02 -0.000e+00 -1.094e-01  6.510e-02 -4.600e-03
#    9.010e-02  6.850e-02  1.160e-02 -5.640e-02 -1.790e-02  3.920e-02
#   -2.820e-02 -1.637e-01  3.203e-01 -3.340e-01 -3.580e-02 -3.789e-01
# ...

# %%
print(X_scaled.shape)
print(pca.components_.T.shape)
# Out:
# (26236, 44)
# (44, 22)

# %%
np.dot(X_scaled, pca.components_.T)
# Out:
# array([[-3.61980756, -1.60753975, -2.12679757, ...,  0.23784538,
#          0.03089448,  0.88390615],
#        [-1.77265485, -0.24643156, -0.01350518, ...,  0.75105568,
#          0.06234678,  0.48008557],
#        [-2.64653451, -0.09397765, -0.81397071, ...,  0.89535084,
#         -0.05902362,  0.72734417],
#        ...,
#        [ 2.81950311, -1.21994511,  0.94091235, ...,  0.55734677,
#         -0.71484663, -0.45198902],
#        [-0.60766148, -1.37441173,  1.94199993, ...,  0.53504272,
#         -0.28872636, -1.21017721],
#        [-0.60766148, -1.37441173,  1.94199993, ...,  0.53504272,
#         -0.28872636, -1.21017721]])

# %%
pca.transform(X_scaled)
# Out:
# array([[-3.61980756, -1.60753975, -2.12679757, ...,  0.23784538,
#          0.03089448,  0.88390615],
#        [-1.77265485, -0.24643156, -0.01350518, ...,  0.75105568,
#          0.06234678,  0.48008557],
#        [-2.64653451, -0.09397765, -0.81397071, ...,  0.89535084,
#         -0.05902362,  0.72734417],
#        ...,
#        [ 2.81950311, -1.21994511,  0.94091235, ...,  0.55734677,
#         -0.71484663, -0.45198902],
#        [-0.60766148, -1.37441173,  1.94199993, ...,  0.53504272,
#         -0.28872636, -1.21017721],
#        [-0.60766148, -1.37441173,  1.94199993, ...,  0.53504272,
#         -0.28872636, -1.21017721]])

# %%
dd = pd.DataFrame(
    pca.transform(X_scaled),
    columns=[f'PC{n}' for n in range(1, pca.n_components_ + 1)]
)
dd.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -3.619808 -1.607540 -2.126798  0.028373  1.160249 -0.479075  2.372810
# 1 -1.772655 -0.246432 -0.013505 -2.373379  0.415743  1.306866 -0.344215
# 2 -2.646535 -0.093978 -0.813971 -1.391128 -0.436085  1.113157 -0.705714
# 3 -0.663599 -2.394230 -0.625401  1.405488  0.144298  0.400411 -0.073412
# 4 -1.538419 -1.037990 -2.738780 -1.363133 -2.537791  1.201814  0.996897
#
#         PC8       PC9      PC10  ...      PC13      PC14      PC15      PC16  \
# 0  0.666233 -1.700169 -1.406499  ... -0.378936 -0.010731  0.715587  0.400034
# 1  0.937001  2.065192  0.711043  ... -1.945050 -0.469603 -1.066628 -0.176741
# 2  0.500191  1.863091 -0.121726  ... -0.932118 -0.785507  0.105367  0.073451
# 3 -0.117376  0.446626 -0.847206  ...  0.403106 -0.391594  0.419313 -0.513801
# 4  2.917596  1.871612 -0.019530  ...  1.136685 -1.617375  0.170008  1.779372
#
#        PC17      PC18      PC19      PC20      PC21      PC22
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(pca.explained_variance_ratio_, marker='o')
plt.xlabel('Principal Component')
plt.ylabel('Variance Ratio')
plt.title('Explained Variance')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.axhline(y=0.95, linestyle='-', color='red', label='95% Variance')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Variance')
plt.title('Cumulative Explained Variance')
plt.grid()
plt.legend()
plt.show()

# %%
import yellowbrick.features as yb
visualizer = yb.PCA(scale=True, proj_features=True, proj_dim=2)
visualizer.fit_transform(dpc)
visualizer.show()
# Out:
# <Axes: title={'center': 'Principal Component Plot'}, xlabel='$PC_1$', ylabel='$PC_2$'>

# %% [markdown]
# #### Random forest, using data of principle component analysis (PCA)

# %%
feature_pca = dd.values
target_pca = RF_fristEXtarget_Values

# %%
print(f"feature_pca.shape: {feature_pca.shape}")
print(f"target_pca.shape: {target_pca.shape}")
# Out:
# feature_pca.shape: (26236, 22)
# target_pca.shape: (26236,)

# %%
X_pcatrain , X_pcatest , y_pcatrain , y_pcatest = train_test_split(
    feature_pca, target_pca, test_size=0.3, random_state=42
)

X_pcatrain.shape,  y_pcatrain.shape, X_pcatest.shape, y_pcatest.shape
# Out:
# ((18365, 22), (18365,), (7871, 22), (7871,))

# %%
## Algorithm : Random Forest Regressor
rfr_pca = rfr_best_params
rfr_pca
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=30, max_features='sqrt',
#                       min_samples_leaf=2, n_estimators=200, random_state=42,
#                       verbose=2)

# %%
cross_validation_pca = cross_validate(rfr_pca, X_pcatrain, y_pcatrain, cv=5, scoring= ['r2', 'neg_mean_squared_error', 'neg_mean_absolute_error'])
# Out:
# building tree 1 of 200
# building tree 2 of 200
# building tree 3 of 200
# building tree 4 of 200
# building tree 5 of 200
# building tree 6 of 200
# building tree 7 of 200
# building tree 8 of 200
# building tree 9 of 200
# building tree 10 of 200
# building tree 11 of 200
# building tree 12 of 200
# building tree 13 of 200
# building tree 14 of 200
# building tree 15 of 200
# building tree 16 of 200
# building tree 17 of 200
# building tree 18 of 200
# building tree 19 of 200
# building tree 20 of 200
# building tree 21 of 200
# building tree 22 of 200
# building tree 23 of 200
# building tree 24 of 200
# building tree 25 of 200
# building tree 26 of 200
# building tree 27 of 200
# building tree 28 of 200
# building tree 29 of 200
# building tree 30 of 200
# building tree 31 of 200
# building tree 32 of 200
# building tree 33 of 200
# building tree 34 of 200
# building tree 35 of 200
# building tree 36 of 200
# building tree 37 of 200
# building tree 38 of 200
# ...

# %%
RESULT_K_FOLD(cross_validation_pca, 5)
# Out:
# R2 mean: 0.78 and R2 of 5 : [0.79 0.76 0.79 0.77 0.79]
# RMSE mean: 17.16 and RMSE of 5 : [16.78 17.66 16.75 17.4  17.19]
# MAE mean: 10.0 and MAE of 5 : [ 9.73 10.33  9.8  10.14 10.  ]

# %%
rfr_pca = rfr_pca.fit(X_pcatrain, y_pcatrain)
# Out:
# building tree 1 of 200
# building tree 2 of 200
# building tree 3 of 200
# building tree 4 of 200
# building tree 5 of 200
# building tree 6 of 200
# building tree 7 of 200
# building tree 8 of 200
# building tree 9 of 200
# building tree 10 of 200
# building tree 11 of 200
# building tree 12 of 200
# building tree 13 of 200
# building tree 14 of 200
# building tree 15 of 200
# building tree 16 of 200
# building tree 17 of 200
# building tree 18 of 200
# building tree 19 of 200
# building tree 20 of 200
# building tree 21 of 200
# building tree 22 of 200
# building tree 23 of 200
# building tree 24 of 200
# building tree 25 of 200
# building tree 26 of 200
# building tree 27 of 200
# building tree 28 of 200
# building tree 29 of 200
# building tree 30 of 200
# building tree 31 of 200
# building tree 32 of 200
# building tree 33 of 200
# building tree 34 of 200
# building tree 35 of 200
# building tree 36 of 200
# building tree 37 of 200
# building tree 38 of 200
# ...

# %%
Metric_result(rfr_pca, X_pcatrain, X_pcatest, y_pcatrain, y_pcatest)
# Out:
# [Parallel(n_jobs=1)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Done  40 tasks      | elapsed:    0.0s
# Score on training data: 0.99
# ------------------------------
# Test MSE: 244.54
# ------------------------------
# Test RMSE : 15.638
# ------------------------------
# Test R2 Score : 0.817
# ------------------------------
# Mean Absolute Error : 8.65
# ------------------------------
# Mean Absolute Percentage Error : 6833447737789875.0
# ------------------------------
# (7871,)
# (7871,)
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.1s finished

# %%
feature_importance(rfr_pca, dpc)
# Out:
# Columns have all : 22
#    feature  importance
# 6      PC7        0.14
# 15    PC16        0.11
# 16    PC17        0.07
# 18    PC19        0.06
# 5      PC6        0.05
# 2      PC3        0.05
# 1      PC2        0.04
# 17    PC18        0.04
# 0      PC1        0.04
# 3      PC4        0.04
# 12    PC13        0.04
# 20    PC21        0.04
# 7      PC8        0.03
# 4      PC5        0.03
# 14    PC15        0.03
# 8      PC9        0.03
# 21    PC22        0.03
# 11    PC12        0.03
# 10    PC11        0.03
# 19    PC20        0.03
# 9     PC10        0.03
# 13    PC14        0.02

# %% [markdown]
# ##

# %% [markdown]
# ## Chapter 4 : Group similar data points regarding bleaching percentages.

# %%
df_grouped = df_forRF.copy()

# %%
df_grouped
# Out:
#        Site_ID  Sample_ID  Latitude_Degrees  Longitude_Degrees  \
# 1         3467   10324754          -17.5750          -149.7833
# 2         1794   10323866           18.3690           -64.5640
# 4         8648   10328029           17.7690           -64.5830
# 5         2180   10324021            9.8220           -75.8910
# 6         9298   10328657           17.8110           -64.6300
# ...        ...        ...               ...                ...
# 41351     9883   10290629           -6.1562            39.1223
# 41352     9884   10290632           -6.1511            39.1266
# 41353    10189   10290452           -3.2600            40.1500
# 41357    15456   10310527           -8.3473           116.0503
# 41358    15456   10310527           -8.3473           116.0503
#
#        Distance_to_Shore  Turbidity  Cyclone_Frequency  Date_Day  Date_Month  \
# 1                1431.62     0.0262              51.20        15           3
# ...

# %%
def Grouping_data(df, col_groupby, name_new_col, cols_keep=None):
    df_new = df.copy()
    df_new = df_new[col_groupby]
    print(f"Groupby name is : {name_new_col}")
    
    return df_new

# %%
df_area_groupby = Grouping_data(df_grouped, ['Latitude_Degrees', 'Longitude_Degrees'] , 'area_groupby')
df_area_groupby
# Out:
# Groupby name is : area_groupby
#        Latitude_Degrees  Longitude_Degrees
# 1              -17.5750          -149.7833
# 2               18.3690           -64.5640
# 4               17.7690           -64.5830
# 5                9.8220           -75.8910
# 6               17.8110           -64.6300
# ...                 ...                ...
# 41351           -6.1562            39.1223
# 41352           -6.1511            39.1266
# 41353           -3.2600            40.1500
# 41357           -8.3473           116.0503
# 41358           -8.3473           116.0503
#
# [26236 rows x 2 columns]

# %%
Other_paper = [ 'Depth_m', 'ClimSST', 'Cyclone_Frequency', 'Turbidity'] # Exposure is object
df_Other_groupby = Grouping_data(df_grouped, Other_paper, 'Other_groupby')
# Out:
# Groupby name is : Other_groupby

# %%
df_grouped.columns
# Out:
# Index(['Site_ID', 'Sample_ID', 'Latitude_Degrees', 'Longitude_Degrees',
#        'Distance_to_Shore', 'Turbidity', 'Cyclone_Frequency', 'Date_Day',
#        'Date_Month', 'Date_Year', 'Depth_m', 'Percent_Bleaching', 'ClimSST',
#        'Temperature_Kelvin', 'Temperature_Mean', 'Temperature_Minimum',
#        'Temperature_Maximum', 'Temperature_Kelvin_Standard_Deviation',
#        'Windspeed', 'SSTA', 'SSTA_Standard_Deviation', 'SSTA_Mean',
#        'SSTA_Minimum', 'SSTA_Maximum', 'SSTA_Frequency',
#        'SSTA_Frequency_Standard_Deviation', 'SSTA_FrequencyMax',
#        'SSTA_FrequencyMean', 'SSTA_DHW', 'SSTA_DHW_Standard_Deviation',
#        'SSTA_DHWMax', 'SSTA_DHWMean', 'TSA', 'TSA_Standard_Deviation',
#        'TSA_Minimum', 'TSA_Maximum', 'TSA_Mean', 'TSA_Frequency',
#        'TSA_Frequency_Standard_Deviation', 'TSA_FrequencyMax',
#        'TSA_FrequencyMean', 'TSA_DHW', 'TSA_DHW_Standard_Deviation',
#        'TSA_DHWMax', 'TSA_DHWMean'],
#       dtype='object')

# %%
col_SSTA = ['SSTA', 
            #'SSTA_Mean', 
            'SSTA_Minimum', 
            'SSTA_Maximum', 
            'SSTA_Standard_Deviation',
            'SSTA_Frequency',
            'SSTA_Frequency_Standard_Deviation',
            'SSTA_FrequencyMax',
            'SSTA_FrequencyMean',
            'SSTA_DHW',
            'SSTA_DHW_Standard_Deviation',
            'SSTA_DHWMax',
            'SSTA_DHWMean',
        ]
df_SSTA_groupby = Grouping_data(df_grouped, col_SSTA, 'SSTA_groupby')
# Out:
# Groupby name is : SSTA_groupby

# %%
col_temperature = ['Temperature_Kelvin', 'Temperature_Mean', 'Temperature_Minimum', 'Temperature_Maximum', 'Temperature_Kelvin_Standard_Deviation']
df_temperature_groupby = Grouping_data(df_grouped, col_temperature, 'temperature_groupby')
# Out:
# Groupby name is : temperature_groupby

# %%
col_TSA = ['TSA',
           'TSA_Standard_Deviation',
           'TSA_Minimum',
           'TSA_Mean',
           'TSA_Frequency',
           'TSA_Frequency_Standard_Deviation',
           'TSA_FrequencyMax',
           'TSA_FrequencyMean',
           'TSA_DHW',
           'TSA_DHW_Standard_Deviation',
           'TSA_DHWMax',
           'TSA_DHWMean'
        ]
df_TSA_groupby = Grouping_data(df_grouped, col_TSA, 'TSA_groupby')
# Out:
# Groupby name is : TSA_groupby

# %% [markdown]
# #### Groupby
# - df_TSA_groupby
# - df_SSTA_groupby
# - df_temperature_groupby
# - df_area_groupby
# - df_Other_groupby

# %%
Linear_correlation(df_TSA_groupby,(9,6))

# %%
df_grouped[['SSTA_Mean']].sum()
# Out:
# SSTA_Mean    0.0
# dtype: float64

# %%
Linear_correlation(df_SSTA_groupby,(9,6))

# %%
Linear_correlation(df_temperature_groupby,(9,6))

# %%
Linear_correlation(df_Other_groupby,(9,6))

# %%
Linear_correlation(df_area_groupby,(9,6))

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# ## Chapter 5 : Model is Average model

# %%
df_forRF.columns
# Out:
# Index(['Site_ID', 'Sample_ID', 'Latitude_Degrees', 'Longitude_Degrees',
#        'Distance_to_Shore', 'Turbidity', 'Cyclone_Frequency', 'Date_Day',
#        'Date_Month', 'Date_Year', 'Depth_m', 'Percent_Bleaching', 'ClimSST',
#        'Temperature_Kelvin', 'Temperature_Mean', 'Temperature_Minimum',
#        'Temperature_Maximum', 'Temperature_Kelvin_Standard_Deviation',
#        'Windspeed', 'SSTA', 'SSTA_Standard_Deviation', 'SSTA_Mean',
#        'SSTA_Minimum', 'SSTA_Maximum', 'SSTA_Frequency',
#        'SSTA_Frequency_Standard_Deviation', 'SSTA_FrequencyMax',
#        'SSTA_FrequencyMean', 'SSTA_DHW', 'SSTA_DHW_Standard_Deviation',
#        'SSTA_DHWMax', 'SSTA_DHWMean', 'TSA', 'TSA_Standard_Deviation',
#        'TSA_Minimum', 'TSA_Maximum', 'TSA_Mean', 'TSA_Frequency',
#        'TSA_Frequency_Standard_Deviation', 'TSA_FrequencyMax',
#        'TSA_FrequencyMean', 'TSA_DHW', 'TSA_DHW_Standard_Deviation',
#        'TSA_DHWMax', 'TSA_DHWMean'],
#       dtype='object')

# %%
df_forRF[['Percent_Bleaching']].mean().round(2)
y_pred_Averagemodel = 13.91

# %%
df_forRF[['Percent_Bleaching']]
# Out:
#        Percent_Bleaching
# 1                   50.7
# 2                   50.9
# 4                   50.9
# 5                   51.0
# 6                   51.3
# ...                  ...
# 41351              100.0
# 41352              100.0
# 41353              100.0
# 41357              100.0
# 41358              100.0
#
# [26236 rows x 1 columns]

# %%
def RMSE(df):
    y_true = df['Percent_Bleaching'].values
    total = 0
    
    for i in range(len(y_true)):
        error = y_true[i] - y_pred_Averagemodel
        total += error**2
    
    rmse = np.sqrt(total / len(y_true))
    return rmse

print(f"RMSE : {RMSE(df_forRF).round(2)}")

def R2_score(df):
    y_true = df['Percent_Bleaching'].values
    
    y_mean = np.mean(y_true)
    
    ss_res = 0  # sum of squared residuals
    ss_tot = 0  # total sum of squares
    
    for i in range(len(y_true)):
        ss_res += (y_true[i] - y_pred_Averagemodel)**2
        ss_tot += (y_true[i] - y_mean)**2
    
    r2 = 1 - (ss_res / ss_tot)
    
    print(f"SS_res : {ss_res.round(1)}")
    print(f"SS_tot : {ss_tot.round(1)}")
    
    return r2

print(f"Percent_bleaching : {y_pred_Averagemodel}")
print("-"*50)
print(f"R2_score (rounded): {R2_score(df_forRF).round(2):.2f}") # predicted less than mean so R2 is negative
# Out:
# RMSE : 37.83
# Percent_bleaching : 13.91
# --------------------------------------------------
# SS_res : 37537285.1
# SS_tot : 35235125.6
# R2_score (rounded): -0.07

# %% [markdown]
# ##

# %% [markdown]
# ## Cluster node Experimental using ANN for reduce dimentional

# %% [markdown]
# #### Groupby
# - df_TSA_groupby
# - df_SSTA_groupby
# - df_temperature_groupby
# - df_area_groupby
# - df_Other_groupby

# %%
df_temperature_groupby
# Out:
#        Temperature_Kelvin  Temperature_Mean  Temperature_Minimum  \
# 1                  303.30            300.73               297.58
# 2                  299.18            300.32               297.12
# 4                  299.70            300.38               296.63
# 5                  303.22            302.02               298.22
# 6                  302.12            300.38               296.98
# ...                   ...               ...                  ...
# 41351              302.26            300.52               295.48
# 41352              302.26            300.52               295.48
# 41353              302.53            299.73               295.42
# 41357              302.51            301.59               297.57
# 41358              302.51            301.59               297.57
#
#        Temperature_Maximum  Temperature_Kelvin_Standard_Deviation
# 1                   305.01                                   1.12
# ...

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.metrics import RootMeanSquaredError, MeanAbsoluteError, MeanSquaredError
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.callbacks import EarlyStopping
# Out:
# WARNING:tensorflow:From c:\Anaconda\Anaconda3\envs\research_env_v2\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def train_test_split(df_feature, df_target, n_train):
    
    n = len(df_feature)
    n_train = n * n_train
    n_train = int(n_train)
    
    return df_feature[:n_train], df_feature[n_train:], df_target[:n_train], df_target[n_train:]

X_train, X_test, y_train, y_test = train_test_split(RF_fristEXfeature, RF_fristEXtarget, 0.7)
X_train.shape, X_test.shape , y_train.shape, y_test.shape
# Out:
# ((18365, 44), (7871, 44), (18365,), (7871,))

# %%
model_temp = Sequential(
    [
        Dense(4, activation= 'linear', input_shape=(X_train.shape[1],)),
        Dense(4, activation= 'linear'),
        Dense(2, activation= 'linear'),
        Dense(4, activation= 'linear'),
    ]
)
# Out:
# WARNING:tensorflow:From c:\Anaconda\Anaconda3\envs\research_env_v2\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model_temp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 180
#
#  dense_1 (Dense)             (None, 4)                 20
#
#  dense_2 (Dense)             (None, 2)                 10
#
#  dense_3 (Dense)             (None, 4)                 12
#
# ...
# Total params: 222 (888.00 Byte)
# Trainable params: 222 (888.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_temp.compile(
    optimizer=Adam(learning_rate=0.5),
    loss='mean_squared_error',
    metrics=[RootMeanSquaredError(), MeanAbsoluteError(), MeanSquaredError()]
    
)

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

#model_temp.fit(X_train, y_train, epochs=100, batch_size=32, verbose=2, validation_data=(X_val, y_val), callbacks=[early_stopping])

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)

fold = 1
for train_idx, val_idx in kf.split(X_pcatrain):

    print(f"Fold {fold}")
    fold += 1
    
    X_train, X_val = X_pcatrain[train_idx], X_pcatrain[val_idx]
    y_train, y_val = y_pcatrain[train_idx], y_pcatrain[val_idx]
    
    print(X_train.shape)
    print(y_train.shape)
# Out:
# Fold 1
# (14692, 22)
# (14692,)
# Fold 2
# (14692, 22)
# (14692,)
# Fold 3
# (14692, 22)
# (14692,)
# Fold 4
# (14692, 22)
# (14692,)
# Fold 5
# (14692, 22)
# (14692,)
